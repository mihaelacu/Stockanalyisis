# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# #10 najvećih igrača na tržištu dionica u 2018.godini prema https://www.investopedia.com/articles/investing/070116/top-performers-sp-500-year.asp
#
#
# #Company Name	       Ticker	   Percent Gain/Loss
# #Apple Inc.	            AAPL	     9.38%
# #Microsoft Corp.	        MSFT	     15.28%
# #Amazon.com Inc.	        AMZN	     45.35%
# #Facebook Inc.	        FB	         10.12%
# #Netflix                 NFLX	     103.91%
# #JP Morgan Chase & Co    JPM	        -2.56%
# #Exxon Mobil Corp.	    XOM	        -1.09%
# #Alphabet Inc C	        GOOG	     6.62%
# #Alphabet Inc A	        GOOGL	     7.19%
# #Johnson & Johnson	    JNJ	        -13.15%

# %%
aapl = pd.read_csv('AAPL.csv', index_col = 'Date')
msft = pd.read_csv('MSFT.csv', index_col = 'Date')
amzn = pd.read_csv('AMZN.csv', index_col = 'Date')
fb = pd.read_csv('FB.csv', index_col = 'Date')
nflx = pd.read_csv('NFLX.csv', index_col = 'Date')
jpm = pd.read_csv('JPM.csv', index_col = 'Date')
xom = pd.read_csv('XOM.csv', index_col = 'Date')
goog = pd.read_csv('GOOG.csv', index_col = 'Date')
googl = pd.read_csv('GOOGL.csv', index_col = 'Date')
jnj = pd.read_csv('JNJ.csv', index_col = 'Date')

# %%
aapl.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  170.160004  172.300003  169.259995  172.259995  168.339050
# 2018-01-03  172.529999  174.550003  171.960007  172.229996  168.309738
# 2018-01-04  172.539993  173.470001  172.080002  173.029999  169.091522
# 2018-01-05  173.440002  175.369995  173.050003  175.000000  171.016678
# 2018-01-08  174.350006  175.610001  173.929993  174.350006  170.381485
#
#               Volume
# Date
# 2018-01-02  25555900
# 2018-01-03  29517900
# 2018-01-04  22434600
# 2018-01-05  23660000
# 2018-01-08  20567800

# %%
msft.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-01-02  86.129997  86.309998  85.500000  85.949997  83.817863  22483800
# 2018-01-03  86.059998  86.510002  85.970001  86.349998  84.207939  26061400
# 2018-01-04  86.589996  87.660004  86.570000  87.110001  84.949089  21912000
# 2018-01-05  87.660004  88.410004  87.430000  88.190002  86.002296  23407100
# 2018-01-08  88.199997  88.580002  87.599998  88.279999  86.090065  22113000

# %%
amzn.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010  1189.010010
# 2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951  1204.199951
# 2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966  1209.589966
# 2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015  1229.140015
# 2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995  1246.869995
#
#              Volume
# Date
# 2018-01-02  2694500
# 2018-01-03  3108800
# 2018-01-04  3022100
# 2018-01-05  3544700
# 2018-01-08  4279500

# %%
fb.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  177.679993  181.580002  177.550003  181.419998  181.419998
# 2018-01-03  181.880005  184.779999  181.330002  184.669998  184.669998
# 2018-01-04  184.899994  186.210007  184.100006  184.330002  184.330002
# 2018-01-05  185.589996  186.899994  184.929993  186.850006  186.850006
# 2018-01-08  187.199997  188.899994  186.330002  188.279999  188.279999
#
#               Volume
# Date
# 2018-01-02  18151900
# 2018-01-03  16886600
# 2018-01-04  13880900
# 2018-01-05  13574500
# 2018-01-08  17994700

# %%
nflx.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  196.100006  201.649994  195.419998  201.070007  201.070007
# 2018-01-03  202.050003  206.210007  201.500000  205.050003  205.050003
# 2018-01-04  206.199997  207.050003  204.000000  205.630005  205.630005
# 2018-01-05  207.250000  210.020004  205.589996  209.990005  209.990005
# 2018-01-08  210.020004  212.500000  208.440002  212.050003  212.050003
#
#               Volume
# Date
# 2018-01-02  10966900
# 2018-01-03   8591400
# 2018-01-04   6029600
# 2018-01-05   7033200
# 2018-01-08   5580200

# %%
jpm.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  107.629997  108.019997  106.809998  107.949997  103.156837
# 2018-01-03  107.860001  108.489998  107.480003  108.059998  103.261963
# 2018-01-04  108.360001  110.029999  108.199997  109.040001  104.741249
# 2018-01-05  109.260002  109.550003  107.779999  108.339996  104.068840
# 2018-01-08  108.150002  108.680000  107.699997  108.500000  104.222534
#
#               Volume
# Date
# 2018-01-02  13578800
# 2018-01-03  11901000
# 2018-01-04  12953700
# 2018-01-05  14155000
# 2018-01-08  12466500

# %%
xom.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-01-02  83.820000  85.199997  83.660004  85.029999  79.834793  11469300
# 2018-01-03  85.160004  86.970001  84.820000  86.699997  81.402748  13957700
# 2018-01-04  86.790001  87.220001  86.430000  86.820000  81.515427  10863000
# 2018-01-05  86.750000  86.879997  85.709999  86.750000  81.449699  11047600
# 2018-01-08  86.699997  87.150002  86.599998  87.139999  81.815865  10927100

# %%
goog.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  1048.339966  1066.939941  1045.229980  1065.000000  1065.000000
# 2018-01-03  1064.310059  1086.290039  1063.209961  1082.479980  1082.479980
# 2018-01-04  1088.000000  1093.569946  1084.001953  1086.400024  1086.400024
# 2018-01-05  1094.000000  1104.250000  1092.000000  1102.229980  1102.229980
# 2018-01-08  1102.229980  1111.270020  1101.619995  1106.939941  1106.939941
#
#              Volume
# Date
# 2018-01-02  1237600
# 2018-01-03  1430200
# 2018-01-04  1004600
# 2018-01-05  1279100
# 2018-01-08  1047600

# %%
googl.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  1053.020020  1075.979980  1053.020020  1073.209961  1073.209961
# 2018-01-03  1073.930054  1096.099976  1073.430054  1091.520020  1091.520020
# 2018-01-04  1097.089966  1104.079956  1094.260010  1095.760010  1095.760010
# 2018-01-05  1103.449951  1113.579956  1101.800049  1110.290039  1110.290039
# 2018-01-08  1111.000000  1119.160034  1110.000000  1114.209961  1114.209961
#
#              Volume
# Date
# 2018-01-02  1588300
# 2018-01-03  1565900
# 2018-01-04  1302600
# 2018-01-05  1512500
# 2018-01-08  1232200

# %%
jnj.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  139.660004  139.949997  138.720001  139.229996  133.745071
# 2018-01-03  139.360001  140.679993  138.899994  140.559998  135.022675
# 2018-01-04  140.449997  141.139999  140.220001  140.550003  135.013062
# 2018-01-05  140.690002  141.820007  140.279999  141.710007  136.127396
# 2018-01-08  141.699997  142.000000  140.919998  141.889999  136.300293
#
#              Volume
# Date
# 2018-01-02  6842100
# 2018-01-03  5350500
# 2018-01-04  4837600
# 2018-01-05  6158800
# 2018-01-08  5129800

# %%
dates = pd.to_datetime(aapl.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(msft.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(amzn.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(fb.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(nflx.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(jpm.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(xom.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(goog.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(googl.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
dates = pd.to_datetime(jnj.index)
dates
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
#dataframe u koju će biti spremljeni podaci za svaku tvrtku

data = pd.DataFrame(index=dates)
data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2018-01-02 00:00:00, 2018-01-03 00:00:00, 2018-01-04 00:00:00, 2018-01-05 00:00:00, 2018-01-08 00:00:00]

# %%
data['AAPL'] = aapl['Adj Close']
data['MSFT'] = msft['Adj Close']
data['AMZN'] = amzn['Adj Close']
data['FB'] = fb['Adj Close']
data['NFLX'] = nflx['Adj Close']
data['JPM'] = jpm['Adj Close']
data['XOM'] = xom['Adj Close']
data['GOOG'] = goog['Adj Close']
data['GOOGL'] = googl['Adj Close']
data['JNJ'] = jnj['Adj Close']
data.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-02  168.339050  83.817863  1189.010010  181.419998  201.070007
# 2018-01-03  168.309738  84.207939  1204.199951  184.669998  205.050003
# 2018-01-04  169.091522  84.949089  1209.589966  184.330002  205.630005
# 2018-01-05  171.016678  86.002296  1229.140015  186.850006  209.990005
# 2018-01-08  170.381485  86.090065  1246.869995  188.279999  212.050003
#
#                    JPM        XOM         GOOG        GOOGL         JNJ
# Date
# 2018-01-02  103.156837  79.834793  1065.000000  1073.209961  133.745071
# 2018-01-03  103.261963  81.402748  1082.479980  1091.520020  135.022675
# 2018-01-04  104.741249  81.515427  1086.400024  1095.760010  135.013062
# 2018-01-05  104.068840  81.449699  1102.229980  1110.290039  136.127396
# 2018-01-08  104.222534  81.815865  1106.939941  1114.209961  136.300293

# %%
#prikaži ponašanje dionica kroz 2018.godinu

data.iloc[:,0:10].plot()
plt.legend(loc='upper left')

# %%
names = []
w = -1
for i in data.columns:
    names.append(i +' change')
for i in names:
    w = w+1
    data[i] = 1-data[data.columns[w]].shift(1)/data[data.columns[w]]

# %%
names
# Out:
# ['AAPL change',
#  'MSFT change',
#  'AMZN change',
#  'FB change',
#  'NFLX change',
#  'JPM change',
#  'XOM change',
#  'GOOG change',
#  'GOOGL change',
#  'JNJ change']

# %%
#dnevna postotna promjena

data.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-02  168.339050  83.817863  1189.010010  181.419998  201.070007
# 2018-01-03  168.309738  84.207939  1204.199951  184.669998  205.050003
# 2018-01-04  169.091522  84.949089  1209.589966  184.330002  205.630005
# 2018-01-05  171.016678  86.002296  1229.140015  186.850006  209.990005
# 2018-01-08  170.381485  86.090065  1246.869995  188.279999  212.050003
#
#                    JPM        XOM         GOOG        GOOGL         JNJ  \
# Date
# 2018-01-02  103.156837  79.834793  1065.000000  1073.209961  133.745071
# 2018-01-03  103.261963  81.402748  1082.479980  1091.520020  135.022675
# 2018-01-04  104.741249  81.515427  1086.400024  1095.760010  135.013062
# 2018-01-05  104.068840  81.449699  1102.229980  1110.290039  136.127396
# 2018-01-08  104.222534  81.815865  1106.939941  1114.209961  136.300293
#
#             AAPL change  MSFT change  AMZN change  FB change  NFLX change  \
# Date
# ...

# %%
#grafovi dnevne postotne promjene

ww = 0
plt.figure(figsize = (20,20))
for i in range(10,20):
    ww = ww+1
    plt.subplot(5,2,ww)
    plt.plot(data.iloc[:,i])
    plt.legend()

# %%
# distribucija dnevne postotne promjene
ww = 0
plt.figure(figsize = (12,9))
for i in range(10,20):
    ww = ww+1
    plt.subplot(4,3,ww)
    plt.hist(data.iloc[:,i], bins=20)
    plt.title(data.columns[i])
    plt.tight_layout()
# Out:
# C:\Anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# # Adjusted closing price

# %%
aapl['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Apple Price data")
plt.show()

# %%
msft['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Microsoft Price data")
plt.show()

# %%
amzn['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Amazon Price data")
plt.show()

# %%
fb['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Facebook Price data")
plt.show()

# %%
nflx['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Netflix Price data")
plt.show()

# %%
jpm['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Jpm Price data")
plt.show()

# %%
xom['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Exxon Mobil Corp Price data")
plt.show()

# %%
goog['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Alphabet Inc C Price data")
plt.show()

# %%
googl['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Alphabet Inc A Price data")
plt.show()

# %%
jnj['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Johnson and Johnson")
plt.show()

# %% [markdown]
# # Calculating the daily and monthly returns for individual stock

# %%
aapl_daily_returns = aapl['Adj Close'].pct_change()

# %%
aapl_daily_returns.plot()

# %%
#daily returns

names2 = []
w = 9
for i in data.columns[0:10]:
    names2.append(i +' daily returns')
for i in names2:
    w = w+1
    data[i] = (1 + data[data.columns[w]]).cumprod()

# %%
data.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-02  168.339050  83.817863  1189.010010  181.419998  201.070007
# 2018-01-03  168.309738  84.207939  1204.199951  184.669998  205.050003
# 2018-01-04  169.091522  84.949089  1209.589966  184.330002  205.630005
# 2018-01-05  171.016678  86.002296  1229.140015  186.850006  209.990005
# 2018-01-08  170.381485  86.090065  1246.869995  188.279999  212.050003
#
#                    JPM        XOM         GOOG        GOOGL         JNJ  ...  \
# Date                                                                     ...
# 2018-01-02  103.156837  79.834793  1065.000000  1073.209961  133.745071  ...
# 2018-01-03  103.261963  81.402748  1082.479980  1091.520020  135.022675  ...
# 2018-01-04  104.741249  81.515427  1086.400024  1095.760010  135.013062  ...
# 2018-01-05  104.068840  81.449699  1102.229980  1110.290039  136.127396  ...
# ...

# %%
data.iloc[:,20:30].plot()

# %% [markdown]
# # weekly changes

# %%
#means
week1 = data.iloc[:,0:10].resample('W').mean()
#medians
week2 = data.iloc[:,0:10].resample('W').median()

# %%
week1.plot()

# %%
dataWeek.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-07  169.189247  84.744297  1207.984985  184.317501  205.435005
# 2018-01-14  171.083145  86.207088  1267.155981  186.225998  214.470001
# 2018-01-21  174.195160  87.423645  1296.939972  179.270000  219.955002
# 2018-01-28  170.211444  90.053250  1365.472022  187.750000  256.694000
# 2018-02-04  162.346628  91.221529  1425.267993  188.671997  273.237994
#
#                    JPM        XOM         GOOG        GOOGL         JNJ
# Date
# 2018-01-07  103.807222  81.050667  1084.027496  1092.695007  134.977051
# 2018-01-14  105.915071  81.579265  1108.717993  1115.968018  138.432825
# 2018-01-21  108.432262  82.048248  1130.260010  1137.317475  141.237797
# 2018-01-28  110.702585  83.083388  1167.245996  1176.264038  138.667212
# 2018-02-04  111.067601  81.813994  1157.761963  1169.371973  134.868982

# %%
#tjedni postotak promjene
names = []
w = -1
for i in week1.columns:
    names.append(i +' change')
for i in names:
    w = w+1
    week1[i] = 1-week1[week1.columns[w]].shift(1)/week1[week1.columns[w]]
    week2[i] = 1-week2[week2.columns[w]].shift(1)/week2[week2.columns[w]]

# %%
week1.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-07  169.189247  84.744297  1207.984985  184.317501  205.435005
# 2018-01-14  171.083145  86.207088  1267.155981  186.225998  214.470001
# 2018-01-21  174.195160  87.423645  1296.939972  179.270000  219.955002
# 2018-01-28  170.211444  90.053250  1365.472022  187.750000  256.694000
# 2018-02-04  162.346628  91.221529  1425.267993  188.671997  273.237994
#
#                    JPM        XOM         GOOG        GOOGL         JNJ  \
# Date
# 2018-01-07  103.807222  81.050667  1084.027496  1092.695007  134.977051
# 2018-01-14  105.915071  81.579265  1108.717993  1115.968018  138.432825
# 2018-01-21  108.432262  82.048248  1130.260010  1137.317475  141.237797
# 2018-01-28  110.702585  83.083388  1167.245996  1176.264038  138.667212
# 2018-02-04  111.067601  81.813994  1157.761963  1169.371973  134.868982
#
#             AAPL change  MSFT change  AMZN change  FB change  NFLX change  \
# Date
# ...

# %%
#kumulativna tjedna promjena 

names2 = []
w = 9
for i in week1.columns[0:10]:
    names2.append(i +' weekly returns')
for i in names2:
    w = w+1
    week1[i] = (1 + week1[week1.columns[w]]).cumprod()
    week2[i] = (1 + week2[week2.columns[w]]).cumprod()

# %%
#mean
week1.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-07  169.189247  84.744297  1207.984985  184.317501  205.435005
# 2018-01-14  171.083145  86.207088  1267.155981  186.225998  214.470001
# 2018-01-21  174.195160  87.423645  1296.939972  179.270000  219.955002
# 2018-01-28  170.211444  90.053250  1365.472022  187.750000  256.694000
# 2018-02-04  162.346628  91.221529  1425.267993  188.671997  273.237994
#
#                    JPM        XOM         GOOG        GOOGL         JNJ  ...  \
# Date                                                                     ...
# 2018-01-07  103.807222  81.050667  1084.027496  1092.695007  134.977051  ...
# 2018-01-14  105.915071  81.579265  1108.717993  1115.968018  138.432825  ...
# 2018-01-21  108.432262  82.048248  1130.260010  1137.317475  141.237797  ...
# 2018-01-28  110.702585  83.083388  1167.245996  1176.264038  138.667212  ...
# ...

# %%
#median
week2.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-07  168.715286  84.578514  1206.894959  184.500000  205.340004
# 2018-01-14  170.381485  86.031555  1254.329956  187.839996  212.520004
# 2018-01-21  174.710655  87.816159  1294.789978  179.095001  220.395004
# 2018-01-28  170.254440  89.620255  1362.540039  187.479996  261.299988
# 2018-02-04  163.618988  91.590157  1429.949951  187.119995  270.299988
#
#                    JPM        XOM         GOOG        GOOGL         JNJ  ...  \
# Date                                                                     ...
# 2018-01-07  103.665402  81.426223  1084.440002  1093.640015  135.017869  ...
# 2018-01-14  105.903542  81.618698  1106.260010  1112.790039  138.461624  ...
# 2018-01-21  108.545128  81.956703  1130.885010  1137.534973  141.160942  ...
# 2018-01-28  111.109863  82.970726  1169.969971  1176.170044  138.711395  ...
# ...

# %%
#grafovi
#mean
week1.iloc[:,20:30].plot()

# %%
#median

week2.iloc[:,20:30].plot()

# %% [markdown]
# # Mjesečne promjene

# %%
month1 = data.iloc[:,0:10].resample('M').mean()
month2 = data.iloc[:,0:10].resample('M').mean()
month1.head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-31  170.044569  87.840769  1309.010946  184.962856  232.908096
# 2018-02-28  164.289279  89.325310  1442.363146  180.269474  271.443683
# 2018-03-31  171.219596  91.020095  1540.367629  173.489522  312.228097
# 2018-04-30  166.645232  91.329421  1468.220471  163.810476  307.466192
# 2018-05-31  182.504684  95.227530  1594.903637  182.930000  331.536819
#
#                    JPM        XOM         GOOG        GOOGL         JNJ
# Date
# 2018-01-31  107.873667  81.989790  1130.770467  1139.394293  137.997352
# 2018-02-28  109.508740  73.563548  1088.206839  1091.880002  126.413659
# 2018-03-31  108.926616  70.629101  1091.490479  1093.769060  125.695370
# 2018-04-30  106.531350  73.475513  1035.696187  1039.951910  124.265954
# 2018-05-31  107.054085  76.419012  1069.275901  1074.852717  119.571107

# %%
# mjesečni postotak promjene
names = []
w = -1
for i in month1.columns:
    names.append(i +' change')
for i in names:
    w = w+1
    month1[i] = 1-month1[month1.columns[w]].shift(1)/month1[month1.columns[w]]
    month2[i] = 1-month2[month2.columns[w]].shift(1)/month2[month2.columns[w]]

# %%
#kumulativna mjesečna promjena

names2 = []
w = 9
for i in month1.columns[0:10]:
    names2.append(i +' monthly returns')
for i in names2:
    w = w+1
    month1[i] = (1 + month1[month1.columns[w]]).cumprod()
    month2[i] = (1 + month2[month2.columns[w]]).cumprod()

# %%
#mean
month1.iloc[:,20:30].plot()
plt.legend(loc='best')

# %%
#median
month2.iloc[:,20:30].plot()

# %% [markdown]
# # Quarterly returns

# %%
quarter1 = data.iloc[:,0:10].resample('Q').mean()
quarter2 = data.iloc[:,0:10].resample('Q').median()
quarter1.head()
# Out:
#                   AAPL        MSFT         AMZN          FB        NFLX  \
# Date
# 2018-03-31  168.656455   89.397689  1430.194260  179.551147  272.217869
# 2018-06-30  178.379872   95.171546  1587.434530  180.704688  340.896877
# 2018-09-30  205.597770  106.888442  1880.693493  181.028570  362.951427
# 2018-12-31  192.581263  106.119148  1665.321779  145.090968  299.767420
#
#                    JPM        XOM         GOOG        GOOGL         JNJ
# Date
# 2018-03-31  108.745442  75.454166  1103.990324  1108.887712  130.154208
# 2018-06-30  105.884463  75.999268  1080.685153  1087.835463  120.953546
# 2018-09-30  110.172875  78.783178  1197.939992  1210.749049  129.762222
# 2018-12-31  104.250390  76.501743  1071.071284  1081.405966  137.244887

# %%
#kvartalna promjena 

names = []
w = -1
for i in quarter1.columns:
    names.append(i +' change')
for i in names:
    w = w+1
    quarter1[i] = 1-quarter1[quarter1.columns[w]].shift(1)/quarter1[quarter1.columns[w]]
    quarter2[i] = 1-quarter2[quarter2.columns[w]].shift(1)/quarter2[quarter2.columns[w]]

# %%
names2 = []
w = 9
for i in quarter1.columns[0:10]:
    names2.append(i +' quarterly returns')
for i in names2:
    w = w+1
    quarter1[i] = (1 + quarter1[quarter1.columns[w]]).cumprod()
    quarter2[i] = (1 + quarter2[quarter2.columns[w]]).cumprod()

# %%
#mean

quarter1.iloc[:,20:30].plot()

# %%
#median
quarter2.iloc[:,20:30].plot()

# %%
data.iloc[:,0:20].head()
# Out:
#                   AAPL       MSFT         AMZN          FB        NFLX  \
# Date
# 2018-01-02  168.339050  83.817863  1189.010010  181.419998  201.070007
# 2018-01-03  168.309738  84.207939  1204.199951  184.669998  205.050003
# 2018-01-04  169.091522  84.949089  1209.589966  184.330002  205.630005
# 2018-01-05  171.016678  86.002296  1229.140015  186.850006  209.990005
# 2018-01-08  170.381485  86.090065  1246.869995  188.279999  212.050003
#
#                    JPM        XOM         GOOG        GOOGL         JNJ  \
# Date
# 2018-01-02  103.156837  79.834793  1065.000000  1073.209961  133.745071
# 2018-01-03  103.261963  81.402748  1082.479980  1091.520020  135.022675
# 2018-01-04  104.741249  81.515427  1086.400024  1095.760010  135.013062
# 2018-01-05  104.068840  81.449699  1102.229980  1110.290039  136.127396
# 2018-01-08  104.222534  81.815865  1106.939941  1114.209961  136.300293
#
#             AAPL change  MSFT change  AMZN change  FB change  NFLX change  \
# Date
# ...

# %%
#korelacija promjena

data.iloc[:,10:20].corr()
# Out:
#               AAPL change  MSFT change  AMZN change  FB change  NFLX change  \
# AAPL change      1.000000     0.696232     0.656717   0.423260     0.550323
# MSFT change      0.696232     1.000000     0.773829   0.528010     0.678074
# AMZN change      0.656717     0.773829     1.000000   0.559398     0.736219
# FB change        0.423260     0.528010     0.559398   1.000000     0.465452
# NFLX change      0.550323     0.678074     0.736219   0.465452     1.000000
# JPM change       0.515207     0.610780     0.506204   0.361940     0.459609
# XOM change       0.434236     0.486709     0.370865   0.307100     0.347870
# GOOG change      0.680407     0.826649     0.750389   0.585788     0.655679
# GOOGL change     0.670540     0.822845     0.739923   0.586685     0.653291
# JNJ change       0.320842     0.426589     0.291855   0.182279     0.248821
#
#               JPM change  XOM change  GOOG change  GOOGL change  JNJ change
# ...

# %%
sns.pairplot(data.iloc[:,10:20], diag_kind='kde')
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Anaconda\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.heatmap(data.iloc[:,10:20].corr(), annot=True, center = 0)

# %%
#najviše koleriraju GOOG I GOOGL S MSFT, AAPL-OM, AMAZONOM,NETFLIXOM
#TAKOĐER JAKA KOLERACIJA IZMEĐU AMAZONA I NETFLIXA
#GOOG I GOOGL SESTRINSKE TVRTKE, 99%

# %% [markdown]
# # Analiza rizika

# %%
#mean
means = data.iloc[:,10:20].mean()
means
# Out:
# AAPL change    -0.000497
# MSFT change     0.000534
# AMZN change     0.000614
# FB change      -0.001552
# NFLX change     0.000549
# JPM change     -0.000443
# XOM change     -0.000821
# GOOG change    -0.000265
# GOOGL change   -0.000260
# JNJ change     -0.000352
# dtype: float64

# %%
#standardna devijacija
stds = data.iloc[:,10:20].std()
stds
# Out:
# AAPL change     0.018188
# MSFT change     0.017840
# AMZN change     0.022890
# FB change       0.025565
# NFLX change     0.029149
# JPM change      0.014037
# XOM change      0.013915
# GOOG change     0.017900
# GOOGL change    0.017938
# JNJ change      0.014267
# dtype: float64

# %%
plt.scatter(means,stds)
plt.xlim()
plt.ylim()
plt.xlabel('Expected returns')
plt.ylabel('Risk')
for i,j in enumerate(means.index):
    
 plt.annotate(j[0:4], (means[i], stds[i]))
